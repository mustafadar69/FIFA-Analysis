# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('players.csv')

# %%
df
# Out:
#        int_player_id                      str_player_name str_positions  \
# 0                  1       Lionel Andrés Messi Cuccittini    RW, ST, CF
# 1                  2  Cristiano Ronaldo dos Santos Aveiro        ST, LW
# 2                  3                            Jan Oblak            GK
# 3                  4                      Kevin De Bruyne       CAM, CM
# 4                  5        Neymar da Silva Santos Júnior       LW, CAM
# ...              ...                                  ...           ...
# 18997          18998                                  张梦炫            CB
# 18998          18999                        Vani Da Silva            ST
# 18999          19000                                   夏奥            CB
# 19000          19001                            Ben Hough            CM
# 19001          19002          Mateo Nicolás Flores Cuevas           CDM
#
#       dt_date_of_birth  int_height  int_weight  int_overall_rating  \
# ...

# %%
df.shape
# Out:
# (19002, 56)

# %%
df.describe()
# Out:
#        int_player_id    int_height    int_weight  int_overall_rating  \
# count   19002.000000  19002.000000  19002.000000        19002.000000
# mean     9501.500000    181.225660     75.046311           65.754868
# std      5485.549243      6.847472      7.078378            6.948835
# min         1.000000    155.000000     50.000000           47.000000
# 25%      4751.250000    176.000000     70.000000           61.000000
# 50%      9501.500000    181.000000     75.000000           66.000000
# 75%     14251.750000    186.000000     80.000000           70.000000
# max     19002.000000    206.000000    110.000000           93.000000
#
#        int_potential_rating  int_best_overall_rating     int_value  \
# count          19002.000000             19002.000000  1.900200e+04
# mean              71.148932                66.784286  2.891449e+06
# std                6.115352                 6.733926  7.733189e+06
# min               48.000000                48.000000  0.000000e+00
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        int_player_id                      str_player_name str_positions  \
# 0                  1       Lionel Andrés Messi Cuccittini    RW, ST, CF
# 1                  2  Cristiano Ronaldo dos Santos Aveiro        ST, LW
# 2                  3                            Jan Oblak            GK
# 3                  4                      Kevin De Bruyne       CAM, CM
# 4                  5        Neymar da Silva Santos Júnior       LW, CAM
# ...              ...                                  ...           ...
# 18997          18998                                  张梦炫            CB
# 18998          18999                        Vani Da Silva            ST
# 18999          19000                                   夏奥            CB
# 19000          19001                            Ben Hough            CM
# 19001          19002          Mateo Nicolás Flores Cuevas           CDM
#
#       dt_date_of_birth  int_height  int_weight  int_overall_rating  \
# ...

# %%
df.columns
# Out:
# Index(['int_player_id', 'str_player_name', 'str_positions', 'dt_date_of_birth',
#        'int_height', 'int_weight', 'int_overall_rating',
#        'int_potential_rating', 'str_best_position', 'int_best_overall_rating',
#        'int_value', 'int_wage', 'int_team_id', 'str_nationality',
#        'int_crossing', 'int_finishing', 'int_heading_accuracy',
#        'int_short_passing', 'int_volleys', 'int_defensive_awareness',
#        'int_standing_tackle', 'int_sliding_tackle', 'int_diving',
#        'int_handling', 'int_kicking', 'int_gk_positioning', 'int_reflexes',
#        'int_aggression', 'int_interceptions', 'int_positioning', 'int_vision',
#        'int_penalties', 'int_composure', 'int_acceleration',
#        'int_sprint_speed', 'int_agility', 'int_reactions', 'int_balance',
#        'int_shot_power', 'int_jumping', 'int_stamina', 'int_strength',
#        'int_long_shots', 'str_preferred_foot', 'int_weak_foot',
# ...

# %%
df.isnull().sum()
# Out:
# int_player_id                        0
# str_player_name                      0
# str_positions                        0
# dt_date_of_birth                     0
# int_height                           0
# int_weight                           0
# int_overall_rating                   0
# int_potential_rating                 0
# str_best_position                    0
# int_best_overall_rating              0
# int_value                            0
# int_wage                             0
# int_team_id                        235
# str_nationality                      0
# int_crossing                         0
# int_finishing                        0
# int_heading_accuracy                 0
# int_short_passing                    0
# int_volleys                          0
# int_defensive_awareness              0
# int_standing_tackle                  0
# int_sliding_tackle                   0
# int_diving                           0
# int_handling                         0
# ...

# %%
df.drop(['str_player_speciality','int_team_id'],axis=1,inplace=True)

# %%
df.drop('str_trait',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# int_player_id                    0
# str_player_name                  0
# str_positions                    0
# dt_date_of_birth                 0
# int_height                       0
# int_weight                       0
# int_overall_rating               0
# int_potential_rating             0
# str_best_position                0
# int_best_overall_rating          0
# int_value                        0
# int_wage                         0
# str_nationality                  0
# int_crossing                     0
# int_finishing                    0
# int_heading_accuracy             0
# int_short_passing                0
# int_volleys                      0
# int_defensive_awareness          0
# int_standing_tackle              0
# int_sliding_tackle               0
# int_diving                       0
# int_handling                     0
# int_kicking                      0
# int_gk_positioning               0
# int_reflexes                     0
# int_aggression                   0
# ...

# %%
df = df.rename(columns = {'str_player_name': 'PlayerName', 'str_positions': 'Positions',
                                       'dt_date_of_birth': 'D.O.B', 'int_height': 'PlayerHeight',
                                       'int_weight': 'PlayerWeight', 'int_overall_rating': 'OverallRating',
                                       'int_potential_rating': 'PotentialRating', 'str_best_position': 'BestPositions',
                                       'int_best_overall_rating': 'BestOverallRating', 'int_value': 'PlayerValue',
                                       'int_wage': 'Wage', 'str_nationality': 'Nationality',
                                       'int_crossing': 'Crossing', 'int_finishing': 'FinishingAccuracy',
                                       'int_heading_accuracy': 'HeadingAccuracy', 'int_short_passing': 'ShortPassing',
                                       'int_volleys': 'Volleys', 'int_defensive_awareness': 'DefensiveAwareness',
                                       'int_standing_tackle': 'StandingTackle', 'int_sliding_tackle': 'SlidingTackle',
                                       'int_diving': 'Diving', 'int_handling': 'Handling',
                                       'int_kicking': 'Kicking', 'int_gk_positioning': 'GkPositioning',
                                       'int_reflexes': 'Reflexes', 'int_aggression': 'Aggression',
                                       'int_interceptions': 'Interceptions', 'int_positioning': 'Positioning',
                                       'int_vision': 'Vision', 'int_penalties': 'Penalties',
                                       'int_composure': 'Composure', 'int_acceleration': 'Acceleration',
                                       'int_sprint_speed': 'SprintSpeed', 'int_agility': 'Agility',
                                       'int_reactions': 'Reactions', 'int_balance': 'Balance',
                                       'int_shot_power': 'ShotPower', 'int_jumping': 'JumpingPower',
                                       'int_stamina': 'Stamina', 'int_strength': 'Strength',
                                       'int_long_shots': 'LongShots', 'str_preferred_foot': 'PreferredFoot',
                                        'int_weak_foot': 'WeakFoot', 'int_skill_moves': 'SkillMoves',
                                       'int_international_reputations': 'InternationalReputations', 'str_work_rate': 'WorkRate',
                                       'str_body_type': 'BodyType', 'int_dribbling': 'Dribbling',
                                       'int_curve': 'Curve', 'int_fk_accuracy': 'FkAccuracy',
                                       'int_long_passing': 'LongPassing', 'int_ball_control': 'BallControl'}, inplace = False)

# %%
df
# Out:
#        int_player_id                           PlayerName   Positions  \
# 0                  1       Lionel Andrés Messi Cuccittini  RW, ST, CF
# 1                  2  Cristiano Ronaldo dos Santos Aveiro      ST, LW
# 2                  3                            Jan Oblak          GK
# 3                  4                      Kevin De Bruyne     CAM, CM
# 4                  5        Neymar da Silva Santos Júnior     LW, CAM
# ...              ...                                  ...         ...
# 18997          18998                                  张梦炫          CB
# 18998          18999                        Vani Da Silva          ST
# 18999          19000                                   夏奥          CB
# 19000          19001                            Ben Hough          CM
# 19001          19002          Mateo Nicolás Flores Cuevas         CDM
#
#             D.O.B  PlayerHeight  PlayerWeight  OverallRating  PotentialRating  \
# ...

# %%
df['D.O.B']=pd.to_datetime(df['D.O.B'])
df['year']=df['D.O.B'].dt.year
df['month']=df['D.O.B'].dt.month

# %%
df
# Out:
#        int_player_id                           PlayerName   Positions  \
# 0                  1       Lionel Andrés Messi Cuccittini  RW, ST, CF
# 1                  2  Cristiano Ronaldo dos Santos Aveiro      ST, LW
# 2                  3                            Jan Oblak          GK
# 3                  4                      Kevin De Bruyne     CAM, CM
# 4                  5        Neymar da Silva Santos Júnior     LW, CAM
# ...              ...                                  ...         ...
# 18997          18998                                  张梦炫          CB
# 18998          18999                        Vani Da Silva          ST
# 18999          19000                                   夏奥          CB
# 19000          19001                            Ben Hough          CM
# 19001          19002          Mateo Nicolás Flores Cuevas         CDM
#
#            D.O.B  PlayerHeight  PlayerWeight  OverallRating  PotentialRating  \
# ...

# %%
df.columns
# Out:
# Index(['int_player_id', 'PlayerName', 'Positions', 'D.O.B', 'PlayerHeight',
#        'PlayerWeight', 'OverallRating', 'PotentialRating', 'BestPositions',
#        'BestOverallRating', 'PlayerValue', 'Wage', 'Nationality', 'Crossing',
#        'FinishingAccuracy', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
#        'DefensiveAwareness', 'StandingTackle', 'SlidingTackle', 'Diving',
#        'Handling', 'Kicking', 'GkPositioning', 'Reflexes', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
#        'ShotPower', 'JumpingPower', 'Stamina', 'Strength', 'LongShots',
#        'PreferredFoot', 'WeakFoot', 'SkillMoves', 'InternationalReputations',
#        'WorkRate', 'BodyType', 'Dribbling', 'Curve', 'FkAccuracy',
#        'LongPassing', 'BallControl', 'year', 'month'],
#       dtype='object')

# %%
df['Nationality']
# Out:
# 0        Argentina
# 1         Portugal
# 2         Slovenia
# 3          Belgium
# 4           Brazil
#            ...
# 18997     China PR
# 18998      England
# 18999     China PR
# 19000      England
# 19001      Bolivia
# Name: Nationality, Length: 19002, dtype: object

# %%
#Top 5 countries with most player

df['Nationality'].value_counts().head(5)

#plt.bar(list(df['Nationality'].value_counts().head().keys()),list(df['Nationality'].value_counts().head()))
# Out:
# England      1705
# Germany      1199
# Spain        1063
# France       1002
# Argentina     932
# Name: Nationality, dtype: int64

# %%
#lowest player countries
df['Nationality'].value_counts().tail(5)
# Out:
# Guatemala    1
# Bermuda      1
# Indonesia    1
# Tanzania     1
# Nicaragua    1
# Name: Nationality, dtype: int64

# %%
#top 5 fastest players

df[['PlayerName','Acceleration']].sort_values(by='Acceleration',ascending=False).head()
# Out:
#                      PlayerName  Acceleration
# 583         Adama Traoré Diarra            97
# 6          Kylian Mbappé Lottin            96
# 1095               Daniel James            96
# 284             Alphonso Davies            96
# 22    Raheem Shaquille Sterling            96

# %%
#top 5 tallest players
df[['PlayerName','PlayerHeight']].sort_values(by='PlayerHeight',ascending=False).head()
# Out:
#                    PlayerName  PlayerHeight
# 10369              Tomáš Holý           206
# 10964         Abdoul Bocar Bâ           203
# 4133   Costel Fane Pantilimon           203
# 12452     Aaron James Chapman           203
# 6644   Vanja Milinković-Savić           202

# %%
#top 5 strongest players
df[['PlayerName','Strength']].sort_values(by='Strength',ascending=False).head(5)
# Out:
#                             PlayerName  Strength
# 10400                Adebayo Akinfenwa        97
# 12270                       Daryl Dike        96
# 84                Romelu Lukaku Menama        95
# 8515   Joyskim Aurélien Dawa Tchakonte        95
# 4945      Armando Jesús Méndez Alcorta        95

# %%
df[['PlayerName','LongPassing']].sort_values(by='LongPassing',ascending=False).head()
# Out:
#                         PlayerName  LongPassing
# 3                  Kevin De Bruyne           93
# 27                      Toni Kroos           93
# 0   Lionel Andrés Messi Cuccittini           91
# 53                      Paul Pogba           91
# 87             Daniel Parejo Muñoz           90

# %%
df[['PlayerName','Wage']].sort_values(by='Wage',ascending=False).head()
# Out:
#                         PlayerName    Wage
# 0   Lionel Andrés Messi Cuccittini  560000
# 3                  Kevin De Bruyne  370000
# 26                     Eden Hazard  350000
# 15                   Karim Benzema  350000
# 27                      Toni Kroos  310000

# %%
df[['PlayerName','ShotPower']].sort_values(by='ShotPower',ascending=False).head()
# Out:
#                               PlayerName  ShotPower
# 263                   Aleksandar Kolarov         95
# 1    Cristiano Ronaldo dos Santos Aveiro         94
# 477            Givanildo Vieira de Souza         94
# 99                  Erling Braut Haaland         93
# 3                        Kevin De Bruyne         91

# %%
df[['PlayerName','LongShots']].sort_values(by='LongShots',ascending=False).head()
# Out:
#                               PlayerName  LongShots
# 0         Lionel Andrés Messi Cuccittini         94
# 1    Cristiano Ronaldo dos Santos Aveiro         93
# 253          James David Rodríguez Rubio         92
# 3                        Kevin De Bruyne         91
# 25                               손흥민 孙兴慜         90

# %%
# Top 5 most penality players
 
df[['PlayerName','Penalties']].sort_values(by='Penalties',ascending=False).head()
# Out:
#                          PlayerName  Penalties
# 16              Sergio Ramos García         92
# 355                       Max Kruse         92
# 4     Neymar da Silva Santos Júnior         92
# 119   Raúl Alonso Jiménez Rodríguez         92
# 1592                     Mark Noble         92

# %%
# Best 5 most high vision players
 
df[['PlayerName','Vision']].sort_values(by='Vision',ascending=False).head()
# Out:
#                          PlayerName  Vision
# 0    Lionel Andrés Messi Cuccittini      95
# 3                   Kevin De Bruyne      94
# 368            Andrés Iniesta Luján      93
# 60        David Josué Jiménez Silva      91
# 271                      Mesut Özil      90

# %%
# Top 5 low weight players
 
df[['PlayerName','PlayerWeight']].sort_values(by='PlayerWeight',ascending=True).head()
# Out:
#                     PlayerName  PlayerWeight
# 11223        Bandar Al Mutairi            50
# 15245       Kevin Raphael Diaz            52
# 17229          Mohsen Abdullah            52
# 10940           Osame Sahraoui            53
# 18069  Juan Diego Nieva Guzmán            54

# %%
sns.countplot(df['PreferredFoot'])
# Out:
# /Users/mustafadar/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='PreferredFoot', ylabel='count'>

# %% [markdown]
# Now we will make the prediction of players expected wage using linear regression.
# But before applying regression algorithm we need to form our dataset according to machine learning requirements.
# So we will remove extra columns:

# %%
df.drop(['int_player_id','PlayerName','year', 'month', 'D.O.B', 'Nationality'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19002 entries, 0 to 19001
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Positions                 19002 non-null  object
#  1   PlayerHeight              19002 non-null  int64
#  2   PlayerWeight              19002 non-null  int64
#  3   OverallRating             19002 non-null  int64
#  4   PotentialRating           19002 non-null  int64
#  5   BestPositions             19002 non-null  object
#  6   BestOverallRating         19002 non-null  int64
#  7   PlayerValue               19002 non-null  int64
#  8   Wage                      19002 non-null  int64
#  9   Crossing                  19002 non-null  int64
#  10  FinishingAccuracy         19002 non-null  int64
#  11  HeadingAccuracy           19002 non-null  int64
#  12  ShortPassing              19002 non-null  int64
#  13  Volleys                   19002 non-null  int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
col=['Positions', 'BestPositions', 'PreferredFoot', 'WorkRate', 'BodyType']
le=LabelEncoder()
for i in col:
  df[i]=le.fit_transform(df[i])

# %%
df
# Out:
#        Positions  PlayerHeight  PlayerWeight  OverallRating  PotentialRating  \
# 0            562           170            72             93               93
# 1            615           187            83             92               92
# 2            222           188            87             91               93
# 3             10           181            70             91               91
# 4            347           175            68             91               91
# ...          ...           ...           ...            ...              ...
# 18997         56           177            70             47               52
# 18998        586           171            58             47               67
# 18999         56           178            66             47               55
# 19000        157           175            65             47               67
# 19001         88           174            68             47               63
#
# ...

# %%
X=df.drop('Wage',axis=1)
y=df['Wage']

# %%
# Splitting dataset into training and testing
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=101)

# %%
# Model Scaling
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression

model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print("Training completed.")
# Out:
# Training completed.

# %%
y_pred=model.predict(x_test)

# %%
# Performance Evaluation
from sklearn import metrics
 
print('Mean Absolute Error =', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error =', metrics.mean_squared_error(y_test, y_pred))
# Out:
# Mean Absolute Error = 4880.505046298826
# Mean Squared Error = 96405781.90480392
